# %% [markdown]
# <h1 style="text-align: center;">CIÊNCIA DE DADOS</h1>
# <h1 style="text-align: center;">Roteiro de Atividade Prática</h1>
# <br>
# <br>
#
# Nome: ______________________________________________________________________________________
#
# Turma: ______________
#
#
# **Componente:** Inteligência Artificial
# <br>
# **Unidade Curricular:** Redes Neurais
# <br>
# **Tema da Semana:** CNNs
# <br>

# %% [markdown]
# # Aula 3: Exercícios de Fixação

# %% [markdown]
# ## Tarefa
#
# - Se as bibliotecas não tiverem instaladas, instale-as.
#
# - Acompanhe as instruções.
#
# - Preencha o código onde está #TO DO
#
# - Execute o código.
#
# - Responda as perguntas e conclua a atividade

# %% [markdown]
# ### Instalação das dependência do tensorflow

# %%
#!pip install --upgrade pip setuptools wheel

# %%
#!pip install tensorflow

# %%
#!conda install anaconda::tensorflow

# %%
#!pip install scikit-learn numpy pandas matplotlib

# %% [markdown]
# ### Imports de dependências

# %%
import numpy as np
import random, os
import numpy as np
from tensorflow.keras import datasets
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv2D, MaxPooling2D, Flatten, Dropout, BatchNormalization
from tensorflow.keras.metrics import Precision, Recall
from tensorflow.keras.models import Model
import tensorflow as tf
import matplotlib.pyplot as plt

# %% [markdown]
# ### Configurações

# %%
SEED = 42


def set_seed(seed=0):
  np.random.seed(seed) 
  tf.random.set_seed(seed) 
  random.seed(seed)
  os.environ['TF_DETERMINISTIC_OPS'] = "1"
  os.environ['TF_CUDNN_DETERMINISM'] = "1"
  os.environ['PYTHONHASHSEED'] = str(seed)

set_seed(SEED)

# %% [markdown]
# ### Leitura dos dados

# %%
(X_train, y_train), (X_test, y_test) = datasets.cifar10.load_data()

# Definir os índices correspondentes às classes "gato" (classe 3) e "cavalo" (classe 7)
cat_horse_indices_train = np.where((y_train == 3) | (y_train == 7))[0]
X_train = X_train[cat_horse_indices_train]
y_train = y_train[cat_horse_indices_train]

cat_horse_indices_test = np.where((y_test == 3) | (y_test == 7))[0]
X_test = X_test[cat_horse_indices_test]
y_test = y_test[cat_horse_indices_test]

# %%
# Normalização dos valores dos pixels para o intervalo 0-1
X_train = X_train / 255.0
X_test = X_test / 255.0

# %% [markdown]
# ### Ajuste de classes para one-hot encoding

# %%
y_train = (y_train == 7).astype(int)
y_test = (y_test == 7).astype(int)

# %% [markdown]
# ### Criação o modelo

# %%
model = Sequential()

# Primeira camada convolucional
model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(32, 32, 3)))
model.add(BatchNormalization())
model.add(MaxPooling2D((2, 2)))
model.add(Dropout(0.5))

# Segunda camada convolucional
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D((2, 2)))
model.add(Dropout(0.5))

#TO DO
# Terceira camada convolucional
model.add(Conv2D(128, (3, 3), activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D((2, 2)))
model.add(Dropout(0.5))

# Flatten
model.add(Flatten())

# Camada totalmente conectada com função de ativação relu
model.add(Dense(32, activation='relu')) 
model.add(Dropout(0.5))

# Camada de saída
model.add(Dense(1, activation='sigmoid'))

# %%
model.compile(optimizer='adam', loss='binary_crossentropy',    metrics=['accuracy', Precision(), Recall()])

# %% [markdown]
# ### Treinamento do modelo

# %%
history = model.fit(X_train, y_train, epochs=5, batch_size=32, validation_data=(X_test, y_test), )

# %% [markdown]
# ### Perguntas e Conclusão

# %% [markdown]
# #### Crie uma cópia do notebook e altere as camadas adicionando uma camada convolucional.
# ##### O resultado ficou melhor adicionando a camada convolucional?
# ##### As métricas val_loss e val_accuracy melhoraram?
